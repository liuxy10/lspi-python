# %%
# !cd /Applications/MATLAB_R2023b.app/extern/engines/python && python3 -m pip install .
# Out:
# Processing /Applications/MATLAB_R2023b.app/extern/engines/python
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for matlabengine: filename=matlabengine-23.2-py3-none-any.whl size=16604 sha256=3baf337849047616e51eabd7fa5e64114fbe62e7d9b5db8c24fa8fb58f70da2d
#   Stored in directory: /private/var/folders/73/zqlptqsn27v4gcmcwd2232t80000gn/T/pip-ephem-wheel-cache-x45dbq4g/wheels/ec/42/d9/27ba066906ee1318b14c946efb108c63e6393260ad1ce2577c
# Successfully built matlabengine
# ...
#   Attempting uninstall: matlabengine
#     Found existing installation: matlabengine 23.2
#     Uninstalling matlabengine-23.2:
#       Successfully uninstalled matlabengine-23.2
# ...

# %%
import matlab.engine    
# Start MATLAB engine
eng = matlab.engine.start_matlab()
# Out:
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 632)
# In PI_Invert_Pendulum (line 42)
# Sample 1: normState = [0.254648, 0.031831], normNextState = [0.256300, 0.050794], actionT = -33.768099, reward = 0.263937sample added at time step = 0 during task 1
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 636)
# In PI_Invert_Pendulum (line 42)
# Sample 2: normState = [0.256300, 0.050794], normNextState = [0.258542, 0.061325], actionT = -0.014624, reward = 0.313399sample added at time step = 1 during task 1
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 636)
# In PI_Invert_Pendulum (line 42)
# Sample 3: normState = [0.258542, 0.061325], normNextState = [0.261209, 0.072026], actionT = -0.358114, reward = 0.373157sample added at time step = 2 during task 1
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 636)
# In PI_Invert_Pendulum (line 42)
# ...

# %%
# Add folder containing your MATLAB function to the MATLAB path (if needed)
eng.addpath('/Users/xinyi/Documents/GitHub/lspi/lspi-python/external/pice/', nargout=0)
# Call LQR function
eng.PI_Invert_Pendulum(nargout=0)
# eng.PI_abstract(nargout=0)
# Out:
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 632)
# In PI_Invert_Pendulum (line 42)
# Sample 1: normState = [0.254648, 0.031831], normNextState = [0.256216, 0.046563], actionT = -16.967611, reward = 0.247571sample added at time step = 0 during task 1
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 636)
# In PI_Invert_Pendulum (line 42)
# Sample 2: normState = [0.256216, 0.046563], normNextState = [0.258289, 0.057108], actionT = -0.086188, reward = 0.293360sample added at time step = 1 during task 1
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 636)
# In PI_Invert_Pendulum (line 42)
# Sample 3: normState = [0.258289, 0.057108], normNextState = [0.260786, 0.067774], actionT = -0.256154, reward = 0.349143sample added at time step = 2 during task 1
# ...
# > In quadprog (line 365)
# In LQR_PolicyIteration/getAction (line 636)
# In PI_Invert_Pendulum (line 42)
# ...
